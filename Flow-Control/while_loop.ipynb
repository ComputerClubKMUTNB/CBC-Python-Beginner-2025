# %% [markdown]
# Python while Loop Statement

# %%
#while loop Syntax

#while loop condition
    #body of the loop

# %%
number = 1

#while loop
while number <= 5:
    print(number)
    number += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
password = int(input("Enter an integer"))

#while loop
while password != 0:
    print(f"You entered {x}")
    password = int(input("Enter an integer between 1-10"))

#outside while loop
print("--------------")
# Out:
# You entered 0
# You entered 0
# You entered 0
# You entered 0
# --------------

# %%
answer = str(input(""))     #unfinished

#while loop
while answer.lower() != "":
    answer = str(input(""))
    print("Are you sure?")

# %% [markdown]
# Indentation Error

# %%
number = 1

#while loop
while number <= 5:
print(number)
    number += 1
# Out:
#   Cell In[12], line 5
#     print(number)
#     ^
# IndentationError: expected an indented block after 'while' statement on line 4

# %% [markdown]
# Infinite while Loop

# %%
number = 1

#while loop
while number <= 5:
    print(number)

    #no break

# %%
number = 1

#while loop
while True:
    print("Mai Hai Break")
# Out:
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# Mai Hai Break
# ...
